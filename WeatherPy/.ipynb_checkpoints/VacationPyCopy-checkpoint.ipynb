# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install gmaps
# Out:
# Requirement already satisfied: gmaps in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (0.9.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from gmaps) (5.0.5)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from gmaps) (7.6.3)
# Requirement already satisfied: six in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from gmaps) (1.15.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from gmaps) (7.21.0)
# Requirement already satisfied: geojson>=2.0.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from gmaps) (2.5.0)
# Requirement already satisfied: pygments in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipython>=5.3.0->gmaps) (2.8.0)
# Requirement already satisfied: pickleshare in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipython>=5.3.0->gmaps) (49.6.0.post20210108)
# Requirement already satisfied: jedi>=0.16 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipython>=5.3.0->gmaps) (0.18.0)
# Requirement already satisfied: decorator in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipython>=5.3.0->gmaps) (4.4.2)
# Requirement already satisfied: colorama in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.16)
# Requirement already satisfied: backcall in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.1.2)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.5.0)
# Requirement already satisfied: jupyter-client in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.11)
# Requirement already satisfied: tornado>=4.2 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.1)
# Requirement already satisfied: ipython-genutils in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (20.3.0)
# Requirement already satisfied: wcwidth in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.2.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.2)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (22.0.3)
# Requirement already satisfied: prometheus-client in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.9.0)
# Requirement already satisfied: nbconvert in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.0.7)
# Requirement already satisfied: argon2-cffi in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.1.0)
# Requirement already satisfied: jinja2 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (300)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.14.5)
# Requirement already satisfied: pycparser in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: defusedxml in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: testpath in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4.4)
# Requirement already satisfied: bleach in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.3.0)
# Requirement already satisfied: async-generator in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.4.3)
# Requirement already satisfied: webencodings in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: packaging in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\brand\.conda\envs\pygmaps\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.4.7)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
csv_path = "output.csv"
csv = "output.csv"
weather_data_df = pd.read_csv("output.csv")
weather_data_df
# Out:
#      Unnamed: 0        city      lat      long   temp  humidity  cloud   wind  \
# 0             0   dorokhovo  55.5506   36.3744  30.20        64     75  15.66
# 1             1       bluff -46.6000  168.3333  73.99        47     12  11.01
# 2             2     mataura -46.1927  168.8643  73.99        47     28  11.01
# 3             3      yulara -25.2406  130.9889  82.40        34      0  14.97
# 4             4      hasaki  35.7333  140.8333  40.69        48     20  18.41
# ..          ...         ...      ...       ...    ...       ...    ...    ...
# 546         546        lamu  -2.2717   40.9020  76.51        86      2   9.75
# 547         547     laizhou  37.1717  119.9214  38.53        74    100  14.36
# 548         548  miles city  46.4083 -105.8406  55.40        26      1  14.97
# 549         549     ternate   0.8000  127.4000  81.34        73    100   6.08
# 550         550    zhigansk  66.7697  123.3711 -33.03        82     20  10.58
#
#     country  date and time
# 0        RU     1614730193
# 1        NZ     1614730193
# 2        NZ     1614730193
# 3        AU     1614730194
# 4        JP     1614730194
# ..      ...            ...
# 546      KE     1614730343
# 547      CN     1614730343
# 548      US     1614730343
# 549      ID     1614730344
# 550      RU     1614730344
#
# [551 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

coordinates =weather_data_df[["lat", "long"]]
humidity = weather_data_df["humidity"].astype(float)

fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(coordinates, weights=humidity, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-464b2b3e63ad> in <module>
#      11 # Store the DataFrame Row
#      12 # NOTE: be sure to update with your DataFrame name
# ---> 13 hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
#      14 locations = hotel_df[["Lat", "Lng"]]
#
# NameError: name 'hotel_df' is not defined

# %%
# Add marker layer ontop of heat map


# Display figure
